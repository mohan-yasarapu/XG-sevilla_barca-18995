# %%
#importing modules and packages

import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
base_url = 'https://understat.com/match/'
match_id = str(input("please enter match id :"))
url = base_url + match_id
# Out:
# please enter match id :18995

# %%
url
# Out:
# 'https://understat.com/match/18995'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content,'lxml')
scripts =soup.find_all('script')

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22486275\x22,\x22minute\x22\x3A\x224\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.9119999694824219\x22,\x22Y\x22\x3A\x220.45599998474121095\x22,\x22xG\x22\x3A\x220.4754866063594818\x22,\x22player\x22\x3A\x22Ivan\x20Rakitic\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222094\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222022\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2218995\x22,\x22h_team\x22\x3A\x22Sevilla\x22,\x22a_team\x22\x3A\x22Barcelona\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x223\x22,\x22date\x22\x3A\x222022\x2D09\x2D03\x2019\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Isco\x22,\x22lastAction\x22\x3A\x22Throughball\x22\x7D,\x7B\x22id\x22\x3A\x22486276\x22,\x22minute\x22\x3A\x2214\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.899000015258789\x22,\x22Y\x22\x3A\x220.7169999694824218\x22,\x22xG\x22\x3A\x220.03740036487579346\x22,\x22player\x22\x3A\x22Marcos\x20Acu\x5Cu00f1a\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228939\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222022\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2218995\x22,\x22h_team\x22\x3A\x22Sevilla\x22,\x22a_team\x22\x3A\x22Barcelona\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x223\x22,\x22date\x22\x3A\x222022\x2D09\x2D03\x2019\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Erik\x20Lamela\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22486282\x22,\x22minute\x22\x3A\x2237\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8630000305175781\x22,\x22Y\x22\x3A\x220.41\x22,\x22xG\x22\x3A\x220.08071151375770569\x22,\x22player\x22\x3A\x22Nemanja\x20Gudelj\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227888\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222022\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2218995\x22,\x22h_team\x22\x3A\x22Sevilla\x22,\x22a_team\x22\x3A\x22Barcelona\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x223\x22,\x22date\x22\x3A\x222022\x2D09\x2D03\x2019\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Erik\x20Lamela\x22
als\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x227981\x22,\x22team_id\x22\x3A\x22138\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Nianzou\x20Kouassi\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.032676730304956436\x22,\x22xGBuildup\x22\x3A\x220.032676730304956436\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22547614\x22\x3A\x7B\x22id\x22\x3A\x22547614\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.03740036487579346\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x228939\x22,\x22team_id\x22\x3A\x22138\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Marcos\x20Acu\x5Cu00f1a\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x222\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220.061638571321964264\x22,\x22xGChain\x22\x3A\x220.15964239835739136\x22,\x22xGBuildup\x22\x3A\x220.08956530690193176\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22547615\x22\x3A\x7B\x22id\x22\x3A\x22547615\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x223\x22,\x22xG\x22\x3A\x220.5133022665977478\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x222094\x22,\x22team_id\x22\x3A\x22138\x22,\x22position\x22\x3A\x22MC\x22,\x22player\x22\x3A\x22Ivan\x20Rakitic\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x223916\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %%
## getting only shots data

strings =scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22470890\\x22,\\x22minute\\x22\\x3A\\x2212\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.91\\x22,\\x22Y\\x22\\x3A\\x220.4809999847412109\\x22,\\x22xG\\x22\\x3A\\x220.08072462677955627\\x22,\\x22player\\x22\\x3A\\x22Ferr\\x5Cu00e1n\\x20Torres\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x226441\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2217338\\x22,\\x22h_team\\x22\\x3A\\x22Barcelona\\x22,\\x22a_team\\x22\\x3A\\x22Rayo\\x20Vallecano\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222022\\x2D04\\x2D24\\x2019\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Pierre\\x2DEmerick\\x20Aubameyang\\x22,\\x22lastAction\\x22\\x3A\\x22None\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22470891\\x22,\\x22minute\\x22\\x3A\\x2212\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.8669999694824219\\x22,\\x22Y\\x22\\x3A\\x220.47\\x22,\\x22xG\\x22\\x3A\\x220.08022822439670563\\
04\\x2D24\\x2019\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Ferr\\x5Cu00e1n\\x20Torres\\x22,\\x22lastAction\\x22\\x3A\\x22BallTouch\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22470894\\x22,\\x22minute\\x22\\x3A\\x2233\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.7280000305175781\\x22,\\x22Y\\x22\\x3A\\x220.28100000381469725\\x22,\\x22xG\\x22\\x3A\\x220.01111910305917263\\x22,\\x22player\\x22\\x3A\\x22Ousmane\\x20Demb\\x5Cu00e9l\\x5Cu00e9\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x223226\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A ...

# %%
 ## stripping unrelated data to get only json data
    
ind_start = strings.index("('") +2
ind_end  = strings.index("')")

json_data = strings[ind_start:ind_end]

json_data = json_data.encode('utf8').decode('unicode_escape')
    
 # converting json string to dictionary   
data =json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '486275',
#    'minute': '4',
#    'result': 'SavedShot',
#    'X': '0.9119999694824219',
#    'Y': '0.45599998474121095',
#    'xG': '0.4754866063594818',
#    'player': 'Ivan Rakitic',
#    'h_a': 'h',
#    'player_id': '2094',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Isco',
#    'lastAction': 'Throughball'},
#   {'id': '486276',
#    'minute': '14',
#    'result': 'MissedShots',
#    'X': '0.899000015258789',
#    'Y': '0.7169999694824218',
#    'xG': '0.03740036487579346',
#    'player': 'Marcos Acuña',
#    'h_a': 'h',
#    'player_id': '8939',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Erik Lamela',
#    'lastAction': 'Pass'},
#   {'id': '486282',
#    'minute': '37',
#    'result': 'BlockedShot',
#    'X': '0.8630000305175781',
#    'Y': '0.41',
#    'xG': '0.08071151375770569',
#    'player': 'Nemanja Gudelj',
#    'h_a': 'h',
#    'player_id': '7888',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Erik Lamela',
#    'lastAction': 'Pass'},
#   {'id': '486283',
#    'minute': '37',
#    'result': 'MissedShots',
#    'X': '0.9109999847412109',
#    'Y': '0.385',
#    'xG': '0.028961842879652977',
#    'player': 'Ivan Rakitic',
#    'h_a': 'h',
#    'player_id': '2094',
#    'situation': 'FromCorner',
#    'season': '2022',
#    'shotType': 'Head',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Marcos Acuña',
#    'lastAction': 'Cross'},
#   {'id': '486286',
#    'minute': '45',
#    'result': 'BlockedShot',
#    'X': '0.8640000152587891',
#    'Y': '0.605999984741211',
#    'xG': '0.032676730304956436',
#    'player': 'Erik Lamela',
#    'h_a': 'h',
#    'player_id': '644',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Marcos Acuña',
#    'lastAction': 'Cross'},
#   {'id': '486287',
#    'minute': '45',
#    'result': 'BlockedShot',
#    'X': '0.88',
#    'Y': '0.54',
#    'xG': '0.08018067479133606',
#    'player': 'Erik Lamela',
#    'h_a': 'h',
#    'player_id': '644',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '486289',
#    'minute': '51',
#    'result': 'SavedShot',
#    'X': '0.8809999847412109',
#    'Y': '0.47299999237060547',
#    'xG': '0.07937512546777725',
#    'player': 'Erik Lamela',
#    'h_a': 'h',
#    'player_id': '644',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Isco',
#    'lastAction': 'Tackle'},
#   {'id': '486293',
#    'minute': '70',
#    'result': 'SavedShot',
#    'X': '0.7019999694824218',
#    'Y': '0.4279999923706055',
#    'xG': '0.008130754344165325',
#    'player': 'Alejandro Gomez',
#    'h_a': 'h',
#    'player_id': '1491',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '486301',
#    'minute': '85',
#    'result': 'SavedShot',
#    'X': '0.705999984741211',
#    'Y': '0.6809999847412109',
#    'xG': '0.0088537922129035',
#    'player': 'Ivan Rakitic',
#    'h_a': 'h',
#    'player_id': '2094',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Erik Lamela',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '486277',
#    'minute': '20',
#    'result': 'BlockedShot',
#    'X': '0.875999984741211',
#    'Y': '0.6120000076293945',
#    'xG': '0.3020194470882416',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Ousmane Dembélé',
#    'lastAction': 'Pass'},
#   {'id': '486278',
#    'minute': '20',
#    'result': 'Goal',
#    'X': '0.985999984741211',
#    'Y': '0.4759999847412109',
#    'xG': '0.9778236150741577',
#    'player': 'Raphinha',
#    'h_a': 'a',
#    'player_id': '8026',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'Head',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '486279',
#    'minute': '23',
#    'result': 'MissedShots',
#    'X': '0.8230000305175781',
#    'Y': '0.29100000381469726',
#    'xG': '0.040842022746801376',
#    'player': 'Raphinha',
#    'h_a': 'a',
#    'player_id': '8026',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '486280',
#    'minute': '30',
#    'result': 'MissedShots',
#    'X': '0.9119999694824219',
#    'Y': '0.735',
#    'xG': '0.0431106835603714',
#    'player': 'Ousmane Dembélé',
#    'h_a': 'a',
#    'player_id': '3226',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Robert Lewandowski',
#    'lastAction': 'Pass'},
#   {'id': '486281',
#    'minute': '35',
#    'result': 'Goal',
#    'X': '0.865',
#    'Y': '0.5259999847412109',
#    'xG': '0.3689872920513153',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Jules Koundé',
#    'lastAction': 'Throughball'},
#   {'id': '486284',
#    'minute': '44',
#    'result': 'MissedShots',
#    'X': '0.9290000152587891',
#    'Y': '0.4779999923706055',
#    'xG': '0.4568481743335724',
#    'player': 'Jules Koundé',
#    'h_a': 'a',
#    'player_id': '6433',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'Head',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Pedri',
#    'lastAction': 'Chipped'},
#   {'id': '486285',
#    'minute': '46',
#    'result': 'MissedShots',
#    'X': '0.8980000305175782',
#    'Y': '0.5479999923706055',
#    'xG': '0.4772443175315857',
#    'player': 'Ousmane Dembélé',
#    'h_a': 'a',
#    'player_id': '3226',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Pedri',
#    'lastAction': 'None'},
#   {'id': '486288',
#    'minute': '49',
#    'result': 'Goal',
#    'X': '0.9690000152587891',
#    'Y': '0.48',
#    'xG': '0.555981457233429',
#    'player': 'Eric Garcia',
#    'h_a': 'a',
#    'player_id': '8045',
#    'situation': 'FromCorner',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Jules Koundé',
#    'lastAction': 'HeadPass'},
#   {'id': '486290',
#    'minute': '57',
#    'result': 'MissedShots',
#    'X': '0.8569999694824219',
#    'Y': '0.45099998474121095',
#    'xG': '0.12237460911273956',
#    'player': 'Ousmane Dembélé',
#    'h_a': 'a',
#    'player_id': '3226',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Raphinha',
#    'lastAction': 'Pass'},
#   {'id': '486291',
#    'minute': '61',
#    'result': 'SavedShot',
#    'X': '0.92',
#    'Y': '0.5309999847412109',
#    'xG': '0.4772126376628876',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Sergi Roberto',
#    'lastAction': 'Cross'},
#   {'id': '486292',
#    'minute': '66',
#    'result': 'MissedShots',
#    'X': '0.774000015258789',
#    'Y': '0.6730000305175782',
#    'xG': '0.033099494874477386',
#    'player': 'Ferrán Torres',
#    'h_a': 'a',
#    'player_id': '6441',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Gavi',
#    'lastAction': 'Pass'},
#   {'id': '486294',
#    'minute': '71',
#    'result': 'MissedShots',
#    'X': '0.7290000152587891',
#    'Y': '0.5029999923706054',
#    'xG': '0.0584409236907959',
#    'player': 'Raphinha',
#    'h_a': 'a',
#    'player_id': '8026',
#    'situation': 'DirectFreekick',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '486295',
#    'minute': '72',
#    'result': 'SavedShot',
#    'X': '0.835',
#    'Y': '0.4420000076293945',
#    'xG': '0.4053570032119751',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Raphinha',
#    'lastAction': 'Throughball'},
#   {'id': '486296',
#    'minute': '72',
#    'result': 'BlockedShot',
#    'X': '0.9269999694824219',
#    'Y': '0.5840000152587891',
#    'xG': '0.4832451641559601',
#    'player': 'Frenkie de Jong',
#    'h_a': 'a',
#    'player_id': '7781',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '486297',
#    'minute': '74',
#    'result': 'MissedShots',
#    'X': '0.9269999694824219',
#    'Y': '0.44',
#    'xG': '0.08137459307909012',
#    'player': 'Anssumane Fati',
#    'h_a': 'a',
#    'player_id': '7967',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'Head',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Frenkie de Jong',
#    'lastAction': 'Chipped'},
#   {'id': '486298',
#    'minute': '78',
#    'result': 'BlockedShot',
#    'X': '0.8369999694824218',
#    'Y': '0.66',
#    'xG': '0.0849655419588089',
#    'player': 'Ferrán Torres',
#    'h_a': 'a',
#    'player_id': '6441',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Sergi Roberto',
#    'lastAction': 'Chipped'},
#   {'id': '486299',
#    'minute': '79',
#    'result': 'MissedShots',
#    'X': '0.8040000152587891',
#    'Y': '0.4979999923706055',
#    'xG': '0.07219516485929489',
#    'player': 'Frenkie de Jong',
#    'h_a': 'a',
#    'player_id': '7781',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Sergi Roberto',
#    'lastAction': 'Pass'},
#   {'id': '486300',
#    'minute': '80',
#    'result': 'BlockedShot',
#    'X': '0.775',
#    'Y': '0.6270000076293946',
#    'xG': '0.03902987018227577',
#    'player': 'Ferrán Torres',
#    'h_a': 'a',
#    'player_id': '6441',
#    'situation': 'OpenPlay',
#    'season': '2022',
#    'shotType': 'RightFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': 'Jordi Alba',
#    'lastAction': 'Pass'},
#   {'id': '486302',
#    'minute': '92',
#    'result': 'MissedShots',
#    'X': '0.7709999847412109',
#    'Y': '0.43900001525878907',
#    'xG': '0.089436374604702',
#    'player': 'Raphinha',
#    'h_a': 'a',
#    'player_id': '8026',
#    'situation': 'DirectFreekick',
#    'season': '2022',
#    'shotType': 'LeftFoot',
#    'match_id': '18995',
#    'h_team': 'Sevilla',
#    'a_team': 'Barcelona',
#    'h_goals': '0',
#    'a_goals': '3',
#    'date': '2022-09-03 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'}]}

# %%
minute = []
x = []
y = []
xg = []
result =[]
team =[]
player =[]
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key =='minute' :
            minute.append(data_home[index][key])
        if key =='X' :
            x.append(data_home[index][key])
        if key =='Y' :
            y.append(data_home[index][key])
        if key =='xG' :
            xg.append(data_home[index][key])
        if key =='result' :
            result.append(data_home[index][key])
        if key =='player' :
            player.append(data_home[index][key])
        if key =='h_team' :
            team.append(data_home[index][key])

            
            
for index in range(len(data_away)):
    for key in data_away[index]:
        if key =='minute' :
            minute.append(data_away[index][key])
        if key =='X' :
            x.append(data_away[index][key])
        if key =='Y' :
            y.append(data_away[index][key])
        if key =='xG' :
            xg.append(data_away[index][key])
        if key =='result' :
            result.append(data_away[index][key])
        if key =='player' :
            player.append(data_away[index][key])
        if key =='a_team' :
            team.append(data_away[index][key])

# %%
## creating data frame
col_names = ['minute','x','y','xg','result','team','player']
df = pd.DataFrame([minute,x,y,xg,result,team,player],index =col_names)
df= df.T

# %%
df
# Out:
#    minute                   x                    y                    xg  \
# 0       4  0.9119999694824219  0.45599998474121095    0.4754866063594818
# 1      14   0.899000015258789   0.7169999694824218   0.03740036487579346
# 2      37  0.8630000305175781                 0.41   0.08071151375770569
# 3      37  0.9109999847412109                0.385  0.028961842879652977
# 4      45  0.8640000152587891    0.605999984741211  0.032676730304956436
# 5      45                0.88                 0.54   0.08018067479133606
# 6      51  0.8809999847412109  0.47299999237060547   0.07937512546777725
# 7      70  0.7019999694824218   0.4279999923706055  0.008130754344165325
# 8      85   0.705999984741211   0.6809999847412109    0.0088537922129035
# 9      20   0.875999984741211   0.6120000076293945    0.3020194470882416
# 10     20   0.985999984741211   0.4759999847412109    0.9778236150741577
# 11     23  0.8230000305175781  0.29100000381469726  0.040842022746801376
# 12     30  0.9119999694824219                0.735    0.0431106835603714
# 13     35               0.865   0.5259999847412109    0.3689872920513153
# 14     44  0.9290000152587891   0.4779999923706055    0.4568481743335724
# 15     46  0.8980000305175782   0.5479999923706055    0.4772443175315857
# 16     49  0.9690000152587891                 0.48     0.555981457233429
# 17     57  0.8569999694824219  0.45099998474121095   0.12237460911273956
# 18     61                0.92   0.5309999847412109    0.4772126376628876
# 19     66   0.774000015258789   0.6730000305175782  0.033099494874477386
# 20     71  0.7290000152587891   0.5029999923706054    0.0584409236907959
# 21     72               0.835   0.4420000076293945    0.4053570032119751
# 22     72  0.9269999694824219   0.5840000152587891    0.4832451641559601
# 23     74  0.9269999694824219                 0.44   0.08137459307909012
# 24     78  0.8369999694824218                 0.66    0.0849655419588089
# 25     79  0.8040000152587891   0.4979999923706055   0.07219516485929489
# 26     80               0.775   0.6270000076293946   0.03902987018227577
# 27     92  0.7709999847412109  0.43900001525878907     0.089436374604702
#
#          result       team              player
# 0     SavedShot    Sevilla        Ivan Rakitic
# 1   MissedShots    Sevilla        Marcos Acuña
# 2   BlockedShot    Sevilla      Nemanja Gudelj
# 3   MissedShots    Sevilla        Ivan Rakitic
# 4   BlockedShot    Sevilla         Erik Lamela
# 5   BlockedShot    Sevilla         Erik Lamela
# 6     SavedShot    Sevilla         Erik Lamela
# 7     SavedShot    Sevilla     Alejandro Gomez
# 8     SavedShot    Sevilla        Ivan Rakitic
# 9   BlockedShot  Barcelona  Robert Lewandowski
# 10         Goal  Barcelona            Raphinha
# 11  MissedShots  Barcelona            Raphinha
# 12  MissedShots  Barcelona     Ousmane Dembélé
# 13         Goal  Barcelona  Robert Lewandowski
# 14  MissedShots  Barcelona        Jules Koundé
# 15  MissedShots  Barcelona     Ousmane Dembélé
# 16         Goal  Barcelona         Eric Garcia
# 17  MissedShots  Barcelona     Ousmane Dembélé
# 18    SavedShot  Barcelona  Robert Lewandowski
# 19  MissedShots  Barcelona       Ferrán Torres
# 20  MissedShots  Barcelona            Raphinha
# 21    SavedShot  Barcelona  Robert Lewandowski
# 22  BlockedShot  Barcelona     Frenkie de Jong
# 23  MissedShots  Barcelona      Anssumane Fati
# 24  BlockedShot  Barcelona       Ferrán Torres
# 25  MissedShots  Barcelona     Frenkie de Jong
# 26  BlockedShot  Barcelona       Ferrán Torres
# 27  MissedShots  Barcelona            Raphinha

# %%
 df.to_csv('Sevilla_Barca', header=True, index=False)

# %%
df=pd.read_csv("Sevilla_Barca.csv")
